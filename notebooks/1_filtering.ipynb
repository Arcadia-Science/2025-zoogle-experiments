# %% [markdown]
# # 1. Filtering
#
# This notebook contains the code for filtering the reprocessed organism selection data.
#
# ## 1.1 Setup
# First, load the necessary libraries.
# Prior to running this notebook, the `zoogletools` package was installed using the following command from the top level of this GitHub repository.
#
# ```bash
# pip install -e .
# ```

# %%
import arcadia_pycolor as apc

import zoogletools as zt

DATA_DIR = "../data/2025-04-21-os-portal-reprocessed/"
# Out:
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /Users/dennis/miniconda3/envs/2025-zoogle/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 1.2 Organism parameters
#
# These parameters are used to configure the organisms whose hits will be filtered.

# %%
# Choose the organisms to filter.
organisms = [
    "Ciona-intestinalis",
    "Salpingoeca-rosetta",
]

# For each organism, choose a color palette for the filtering funnel plot.
organism_color_palettes = {
    "Ciona-intestinalis": apc.Gradient(
        name="yellows",
        colors=apc.palettes.yellow_shades.colors,
    )
    .resample_as_palette(7)
    .colors,
    "Salpingoeca-rosetta": apc.gradients.blues.resample_as_palette(6).colors,
}

# Choose a version suffix for the filtered hits and funnel plot files.
version_suffix = "v3.2"

# %% [markdown]
# ## 1.3 Running the filtering pipeline
#
# This section contains the code for running the filtering pipeline.
# This filtering relies on the default filtering pipeline, which is defined in the `zoogletools.filtering` module. You can also define your own filtering pipeline by creating a new F`ilteringPipeline` object and adding your own `Filter`s.

# %%
results = {}

for organism in organisms:
    filtered_hits, filter_counts = zt.filtering.filter_organism_proteins(
        target_organism=organism,
        data_dirpath=DATA_DIR,
        disease_data_filepath="../data/2025-04-21-merged-disease-datasets.tsv",
    )

    results[organism] = {
        "filtered_hits": filtered_hits,
        "filter_counts": filter_counts,
    }

    filtered_hits.to_csv(
        f"{organism}_filtered_hits_{version_suffix}.tsv",
        sep="\t",
    )

    fig = zt.plotting.create_funnel_plot(
        filter_counts,
        title=f"{organism} filtering",
        save_filepath=f"figures/{organism}_filtering_funnel_plot_{version_suffix}.html",
        width=550,
        color_list=organism_color_palettes[organism],
    )

    fig.show()

    final_table = zt.filtering.create_final_filtered_sheet(
        filtered_hits,
        f"{organism}_filtered_hits_{version_suffix}.tsv",
    )

    display(final_table)
# Out:
#     gene_symbol                                      disease_names  \
# 0         IMPA1    Intellectual disability, autosomal recessive 59
# 1         FCHO1                                Immunodeficiency 76
# 2          NAXE  Encephalopathy, progressive, early-onset, with...
# 3         KANK1            Cerebral palsy, spastic quadriplegic, 2
# 4        RNF213                                 Moyamoya disease 2
# ..          ...                                                ...
# 187      CEP295                                 Seckel syndrome 11
# 188      FBXO28     Developmental and epileptic encephalopathy 100
# 189       NUP88              Fetal akinesia deformation sequence 4
# 190      SUPT7L                 FISCHER-ZIRNSAK PROGEROID SYNDROME
# 191        SOBP  Intellectual disability, anterior maxillary pr...
#
#     orphanet_highest_prevalence_class  \
# 0                                 NaN
# 1                                 NaN
# 2                          <1/1000000
# 3                          <1/1000000
# 4                          1-9/100000
# ..                                ...
# 187                               NaN
# 188                           Unknown
# 189                       1-9/1000000
# 190                               NaN
# 191                        <1/1000000
#
#                                   orphanet_prevalences human_protein  \
# 0                                                  NaN        P29218
# 1                                                  NaN        O14526
# 2         11 cases (Worldwide); <1/1000000 (Worldwide)        Q8NCW5
# 3         17 cases (Worldwide); <1/1000000 (Worldwide)        Q14678
# 4    1/135,135 (Japan); 1/16,129 (Japan); 1/232,558...        Q63HN8
# ..                                                 ...           ...
# 187                                                NaN        Q9C0D2
# 188                                Unknown (Worldwide)        Q9NVF7
# 189            1/166,667 (Europe); <1/1000000 (Europe)        Q99567
# 190                                                NaN        O94864
# 191        7 cases (Worldwide); <1/1000000 (Worldwide)        A7XYQ1
#
#      trait_distance  percentile  pvalue_rowwise  pvalue_colwise  \
# 0          0.903045    0.004310          0.0000          0.0170
# 1          1.103326    0.005747          0.0000          0.0000
# 2          1.321808    0.006849          0.0000          0.0000
# 3          1.267654    0.007042          0.0145          0.0000
# 4          1.101398    0.007576          0.0000          0.0217
# ..              ...         ...             ...             ...
# 187        4.791067    0.909091          0.8616          0.0427
# 188        3.839233    0.933333          0.8672          0.0000
# 189        5.013818    1.000000          0.9540          0.0000
# 190        4.295183    1.000000          0.9504          0.0000
# 191        4.398984    1.000000          0.9396          0.0000
#
#     organism_protein  portfolio_rank  \
# 0             F6TKL9             1.0
# 1             F6V4B3             1.0
# 2             H2Y1D7             1.0
# 3             F7ALU8             2.0
# 4             F6PRC5             1.0
# ..               ...             ...
# 187           H2Y0Y1            20.0
# 188           F7B6K5            14.0
# 189           F6ZIK8            24.0
# 190           F6ZKQ7            20.0
# 191           F6XAY2            17.0
#
#                                                 zoogle  \
# 0    https://zoogle.arcadiascience.com/search?gene=...
# 1    https://zoogle.arcadiascience.com/search?gene=...
# 2    https://zoogle.arcadiascience.com/search?gene=...
# 3    https://zoogle.arcadiascience.com/search?gene=...
# 4    https://zoogle.arcadiascience.com/search?gene=...
# ..                                                 ...
# 187  https://zoogle.arcadiascience.com/search?gene=...
# 188  https://zoogle.arcadiascience.com/search?gene=...
# 189  https://zoogle.arcadiascience.com/search?gene=...
# 190  https://zoogle.arcadiascience.com/search?gene=...
# 191  https://zoogle.arcadiascience.com/search?gene=...
#
#                                                   omim  \
# 0    https://omim.org/entry/602064?search=impa1&hig...
# 1    https://omim.org/entry/613437?search=fcho1&hig...
# 2    https://omim.org/entry/608862?search=naxe&high...
# 3    https://omim.org/entry/607704?search=kank1&hig...
# 4    https://omim.org/entry/613768?search=rnf213&hi...
# ..                                                 ...
# 187  https://omim.org/entry/617728?search=cep295&hi...
# 188  https://omim.org/entry/609100?search=fbxo28&hi...
# 189  https://omim.org/entry/602552?search=nup88&hig...
# 190  https://omim.org/entry/612762?search=supt7l&hi...
# 191  https://omim.org/entry/613667?search=sobp&high...
#
#                                               orphanet  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    https://www.orpha.net/en/disease/list/gene/KAN...
# 4    https://www.orpha.net/en/disease/list/gene/RNF...
# ..                                                 ...
# 187                                               None
# 188  https://www.orpha.net/en/disease/list/gene/FBX...
# 189                                               None
# 190                                               None
# 191  https://www.orpha.net/en/disease/list/gene/SOB...
#
#                                            opentargets  \
# 0    https://platform.opentargets.org/target/ENSG00...
# 1    https://platform.opentargets.org/target/ENSG00...
# 2    https://platform.opentargets.org/target/ENSG00...
# 3    https://platform.opentargets.org/target/ENSG00...
# 4    https://platform.opentargets.org/target/ENSG00...
# ..                                                 ...
# 187  https://platform.opentargets.org/target/ENSG00...
# 188  https://platform.opentargets.org/target/ENSG00...
# 189  https://platform.opentargets.org/target/ENSG00...
# 190  https://platform.opentargets.org/target/ENSG00...
# 191  https://platform.opentargets.org/target/ENSG00...
#
#                                    marrvel
# 0      https://marrvel.org/human/gene/3612
# 1     https://marrvel.org/human/gene/23149
# 2    https://marrvel.org/human/gene/128240
# 3     https://marrvel.org/human/gene/23189
# 4     https://marrvel.org/human/gene/57674
# ..                                     ...
# 187   https://marrvel.org/human/gene/85459
# 188   https://marrvel.org/human/gene/23219
# 189    https://marrvel.org/human/gene/4927
# 190    https://marrvel.org/human/gene/9913
# 191   https://marrvel.org/human/gene/55084
#
# [192 rows x 16 columns]
#     gene_symbol                                      disease_names  \
# 0        CDC14A   Autosomal recessive nonsyndromic hearing loss 32
# 1           DDC  Deficiency of aromatic-L-amino-acid decarboxylase
# 2          TNIK    Intellectual disability, autosomal recessive 54
# 3         HMGB3  X-linked colobomatous microphthalmia-microceph...
# 4        CHCHD2           Parkinson disease 22, autosomal dominant
# ..          ...                                                ...
# 148      PTRHD1  Neurodevelopmental disorder with early-onset p...
# 149     CAMSAP1  Cortical dysplasia, complex, with other brain ...
# 150      PHYKPL                            Phosphohydroxylysinuria
# 151        RTTN  Microcephalic primordial dwarfism due to RTTN ...
# 152        DPH5  Neurodevelopmental disorder with short stature...
#
#     orphanet_highest_prevalence_class  \
# 0                             Unknown
# 1                          <1/1000000
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 148                               NaN
# 149                               NaN
# 150                               NaN
# 151                        <1/1000000
# 152                               NaN
#
#                               orphanet_prevalences human_protein  \
# 0                              Unknown (Worldwide)        Q9UNH5
# 1    140 cases (Worldwide); <1/1000000 (Worldwide)        P20711
# 2                                              NaN        Q9UKE5
# 3                                              NaN        O15347
# 4                                              NaN        Q9Y6H1
# ..                                             ...           ...
# 148                                            NaN        Q6GMV3
# 149                                            NaN        Q5T5Y3
# 150                                            NaN        Q8IUZ5
# 151   28 cases (Worldwide); <1/1000000 (Worldwide)        Q86VV8
# 152                                            NaN        Q9H2P9
#
#      trait_distance  percentile  pvalue_rowwise  pvalue_colwise  \
# 0          1.861257    0.004386          0.0000          0.0085
# 1          1.124221    0.004878          0.0000          0.0085
# 2          0.779315    0.005051          0.0000          0.0000
# 3          0.775353    0.009849          0.0336          0.0000
# 4          1.963659    0.013333          0.0206          0.0000
# ..              ...         ...             ...             ...
# 148        4.367880    0.846154          0.8262          0.0222
# 149        5.392030    0.894977          0.8911          0.0000
# 150        5.509309    0.901754          0.9097          0.0180
# 151        4.682612    0.926829          0.9008          0.0458
# 152        6.254149    0.967742          0.9542          0.0438
#
#     organism_protein  portfolio_rank  \
# 0             F2ULW5             1.0
# 1             F2UCR6             1.0
# 2             F2USE6             1.0
# 3             F2U4M4            15.0
# 4             F2UJH6             2.0
# ..               ...             ...
# 148           F2U0Q1            33.0
# 149           F2UGQ1            66.0
# 150           F2TXT5            87.0
# 151           F2UMH2            38.0
# 152           F2UF17            60.0
#
#                                                 zoogle  \
# 0    https://zoogle.arcadiascience.com/search?gene=...
# 1    https://zoogle.arcadiascience.com/search?gene=...
# 2    https://zoogle.arcadiascience.com/search?gene=...
# 3    https://zoogle.arcadiascience.com/search?gene=...
# 4    https://zoogle.arcadiascience.com/search?gene=...
# ..                                                 ...
# 148  https://zoogle.arcadiascience.com/search?gene=...
# 149  https://zoogle.arcadiascience.com/search?gene=...
# 150  https://zoogle.arcadiascience.com/search?gene=...
# 151  https://zoogle.arcadiascience.com/search?gene=...
# 152  https://zoogle.arcadiascience.com/search?gene=...
#
#                                                   omim  \
# 0    https://omim.org/entry/603504?search=cdc14a&hi...
# 1    https://omim.org/entry/107930?search=ddc&highl...
# 2    https://omim.org/entry/610005?search=tnik&high...
# 3    https://omim.org/entry/300193?search=hmgb3&hig...
# 4    https://omim.org/entry/616244?search=chchd2&hi...
# ..                                                 ...
# 148  https://omim.org/entry/617342?search=ptrhd1&hi...
# 149  https://omim.org/entry/613774?search=camsap1&h...
# 150  https://omim.org/entry/614683?search=phykpl&hi...
# 151  https://omim.org/entry/610436?search=rttn&high...
# 152  https://omim.org/entry/611075?search=dph5&high...
#
#                                               orphanet  \
# 0    https://www.orpha.net/en/disease/list/gene/CDC...
# 1    https://www.orpha.net/en/disease/list/gene/DDC...
# 2    https://www.orpha.net/en/disease/list/gene/TNI...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 148                                               None
# 149                                               None
# 150                                               None
# 151  https://www.orpha.net/en/disease/list/gene/RTT...
# 152                                               None
#
#                                            opentargets  \
# 0    https://platform.opentargets.org/target/ENSG00...
# 1    https://platform.opentargets.org/target/ENSG00...
# 2    https://platform.opentargets.org/target/ENSG00...
# 3    https://platform.opentargets.org/target/ENSG00...
# 4    https://platform.opentargets.org/target/ENSG00...
# ..                                                 ...
# 148  https://platform.opentargets.org/target/ENSG00...
# 149  https://platform.opentargets.org/target/ENSG00...
# 150  https://platform.opentargets.org/target/ENSG00...
# 151  https://platform.opentargets.org/target/ENSG00...
# 152  https://platform.opentargets.org/target/ENSG00...
#
#                                    marrvel
# 0      https://marrvel.org/human/gene/8556
# 1      https://marrvel.org/human/gene/1644
# 2     https://marrvel.org/human/gene/23043
# 3      https://marrvel.org/human/gene/3149
# 4     https://marrvel.org/human/gene/51142
# ..                                     ...
# 148  https://marrvel.org/human/gene/391356
# 149  https://marrvel.org/human/gene/157922
# 150   https://marrvel.org/human/gene/85007
# 151   https://marrvel.org/human/gene/25914
# 152   https://marrvel.org/human/gene/51611
#
# [153 rows x 16 columns]
